# %%
# %pip show pymupdf
# Out:
# Name: PyMuPDF
# Version: 1.26.7
# Summary: A high performance Python library for data extraction, analysis, conversion & manipulation of PDF (and other) documents.
# Home-page:
# Author: Artifex
# Author-email: support@artifex.com
# License: Dual Licensed - GNU AFFERO GPL 3.0 or Artifex Commercial License
# Location: c:\Users\82104\miniconda3\envs\ai\Lib\site-packages
# Requires:
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymupdf
import tool

# %%
def pdf_to_text(pdf_file_path: str):
    doc = pymupdf.open(pdf_file_path)

    header_height = 80
    footer_height = 80

    full_text = ''

    for page in doc:
        rect = page.rect # 페이지 크기 가져오기
        
        #rect.width:400,rect.height:800 이라고 가정시
        #clip(시작x, 시작y, 끝x, 끝y), 0,0(왼쪽 상단(x,y)),clip(0,0,400,80)
        header = page.get_text(clip=(0, 0, rect.width , header_height))
        #clip(0,720(800-80),400,80)
        footer = page.get_text(clip=(0, rect.height - footer_height, rect.width , footer_height))
        #clip(0,80,400,720)
        text = page.get_text(clip=(0, header_height, rect.width , rect.height - footer_height))
    
        full_text += text + '\n------------------------------------\n'


    txt_file_path = f'data/pdf_text.txt'

    with open(txt_file_path, 'w', encoding='utf-8') as f:
        f.write(full_text)

    return txt_file_path

# %%
def summarize_txt(file_path: str, ): 
    
    # 주어진 텍스트 파일을 읽어들인다.
    with open(file_path, 'r', encoding='utf-8') as f:
        txt = f.read()

    # 요약을 위한 시스템 프롬프트를 생성한다.

    role = '요약 시스템이야'
    prompt = f''' 
     아래 글을 읽고, 저자의 문제 인식과 주장을 파악하고, 주요 내용을 요약하라. 

    작성해야 하는 포맷은 다음과 같다. 
    
    ## 제목

    ## 저자의 문제 인식 및 주장 (15문장 이내)
    
    ## 저자 소개

    
    =============== 이하 텍스트 ===============

    { txt }
    '''

    return tool.answer(role,prompt,output='text')

# %%
pdf_file_path = "data/과정기반작물모형을이용한웹기반밀재배관리의사결정지원시스템설계및구축.pdf"
file = pdf_to_text(pdf_file_path)
summary = summarize_txt(file)
print(summary)
# Out:
# ## 제목
# 웹 기반 밀 재배관리 의사결정 지원시스템 설계 및 구축
#
# ## 저자의 문제 인식 및 주장
# 저자는 한국의 밀 소비량이 증가하고 있지만 자급률이 1%에 불과하다는 문제를 인식하고, 이를 해결하기 위해 안정적인 밀 생산 기반을 마련할 필요성을 강조한다. 정부의 밀 산업 중장기 발전대책과 자급률 목표를 언급하며, 밀 재배면적 확대와 생산량 증대를 위한 체계적인 관리의 중요성을 주장한다. 특히, 기상환경 조절이 어려운 노지작물의 특성을 고려하여, 디지털 농업 기술을 활용한 의사결정 지원 시스템(DSS)의 필요성을 제기한다. 이 시스템은 과정기반 작물모형(APSIM)을 활용하여 기상 데이터를 분석하고, 실시간으로 밀의 잠재 생산량을 예측함으로써 농가의 의사결정을 지원할 수 있다. 저자는 이 시스템이 농가의 경험 부족을 보완하고, 자연재해에 대한 선제적 대응을 가능하게 할 것이라고 주장한다. 또한, 향후 시스템의 고도화를 통해 국내 밀 생산량과 품질을 향상시킬 수 있는 가능성을 제시한다.
#
# ## 저자 소개
# 김솔희, 석승원, 청리광, 장태일, 김태곤은 전북대학교 스마트농업학과 및 농촌건설공학과의 연구자들로, 디지털 농업 및 작물 재배 관리 시스템 개발에 대한 전문성을 가지고 있다. 이들은 농업 생산성 향상 및 스마트 농업 기술의 적용을 통해 농업의 경쟁력을 높이기 위한 연구를 수행하고 있다.
