# %% [markdown]
# ### single turn

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")  # 환경 변수에서 API 키 가져오기

client = OpenAI(api_key=api_key)  # 오픈AI 클라이언트의 인스턴스 생성

# %%
while True:
    user_input = input("사용자: ")

    if user_input == "exit":
        break

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        temperature=0.9,
        messages=[
            {"role": "system", "content": "너는 사용자를 도와주는 상담사야."},
            {"role": "user", "content": user_input},
        ],
    )
    print("AI: " + response.choices[0].message.content)
# Out:
# AI: 네, 두바이는 기후가 매우 더운 도시입니다. 특히 여름철에는 기온이 40도 이상으로 올라갈 수 있으며, 습도도 높아 더운 날씨가 더욱 힘들게 느껴질 수 있습니다. 겨울철에는 비교적 온화한 기온을 경험할 수 있지만, 여전히 따뜻한 날씨가 지속됩니다. 두바이를 방문할 계획이 있다면, 더운 날씨에 대비하여 적절한 준비를 하는 것이 좋습니다.
# AI: 미네소타는 미국 중북부에 위치한 주로, 특히 아름다운 자연경관과 다양한 문화로 유명합니다. 미네소타는 호수가 많고, 특히 미네소타 호수와 같은 큰 호수들이 있어 여름철에 수상 스포츠와 낚시로 인기가 높습니다. 또한, 미네소타주에는 메트로폴리탄 지역인 미니애폴리스와 세인트폴이 있으며, 이 지역은 활발한 예술과 문화 활동으로 유명합니다.
#
# 미네소타의 경제는 농업, 제조업, 서비스업 등이 다양하게 이루어져 있으며, 특히 의료와 금융 서비스 분야에서 강점을 보이고 있습니다. 또한, 미네소타는 세계적인 기업들이 많이 본사를 두고 있어 경제적으로도 중요한 주입니다.
#
# 더 specific한 정보나 궁금한 점이 있다면 말씀해 주세요!
# AI: 어떤 도움이 필요하신지 말씀해주시면 도와드리겠습니다. 질문이나 고민이 있다면 언제든지 이야기해 주세요.

# %% [markdown]
# ### Multi turn

# %%
# ①
def get_ai_response(messages):
    response = client.chat.completions.create(
        model="gpt-4o-mini",  # 응답 생성에 사용할 모델 지정
        temperature=0.9,  # 응답 생성에 사용할 temperature 설정
        messages=messages,  # 대화 기록을 입력으로 전달
    )
    return response.choices[0].message.content  # 생성된 응답의 내용 반환

messages = [
    {"role": "system", "content": "너는 사용자를 도와주는 상담사야."},  # 초기 시스템 메시지
]

while True:
    user_input = input("사용자: ")  # 사용자 입력 받기

    if user_input == "exit":  # ② 사용자가 대화를 종료하려는지 확인인
        break
    
    messages.append({"role": "user", "content": user_input})  # 사용자 메시지를 대화 기록에 추가 
    ai_response = get_ai_response(messages)  # 대화 기록을 기반으로 AI 응답 가져오기
    messages.append({"role": "assistant", "content": ai_response})  # AI 응답 대화 기록에 추가하기

    print("AI: " + ai_response)  # AI 응답 출력
# Out:
# AI: 안녕하세요! 어떻게 도와드릴까요? 어떤 고민이나 질문이 있으신가요?
# AI: 네, 두바이는 매우 더운 도시입니다. 여름철에는 기온이 40도 이상까지 오르는 경우가 많고, 습도도 높은 편입니다. 특히 6월부터 9월까지는 가장 더운 시기로, 외출 시 주의가 필요합니다. 겨울철인 11월에서 2월 사이에는 온도가 조금 더 시원해지지만, 여전히 따뜻한 날씨가 계속됩니다. 두바이를 방문할 계획이시라면, 적절한 준비와 일정 계획이 필요할 것입니다! 추가로 궁금한 점이 있으신가요?
# AI: 미네소타는 사계절이 뚜렷한 지역으로, 여름과 겨울의 온도 차가 큰 편입니다. 여름철에는 기온이 25도에서 30도 사이로 상승하며, 때때로 더 더워지는 날도 있습니다. 반면 겨울철인 12월부터 2월까지는 매우 추워서 기온이 영하로 떨어지는 경우가 많고, 특히 북부 지역에서는 영하 20도 이하로 내려가는 일도 있습니다. 그래서 미네소타는 여름에는 따뜻하고, 겨울에는 추운 기후를 가지고 있다고 할 수 있습니다. 미네소타에 대해 더 알고 싶은 점이 있나요?
